# %%
import pandas as pd

# %%
coffee = pd.read_csv('./coffee.csv')

# %%
##csv is good but not the best file format 
##size of csv files are very huge 
## feather file formats are better
## parquet files are very very small files for data analytics purposes 
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
results = pd.read_parquet('./results.parquet')
olympics_data = pd.read_excel('./olympics-data.xlsx')
bios= pd.read_csv('./bios.csv')

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
olympics_data.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          20
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          20
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
## loc and iloc
coffee.loc[0:4,["Day","Units Sold"]]
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          20
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35

# %%
coffee.iloc[:,[0,2]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          20
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
coffee.reset_index(drop=True, inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          20
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[0:3]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          20
# 2  Tuesday    Espresso          30
# 3  Tuesday       Latte          20

# %%
##iloc only lets us use index values

coffee.loc[1,"Units Sold"]= 20

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          20
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.iat[0,1]
# Out:
# 'Espresso'

# %%
coffee["Units Sold"]
# Out:
# 0     25
# 1     20
# 2     30
# 3     20
# 4     35
# 5     25
# 6     40
# 7     30
# 8     45
# 9     35
# 10    45
# 11    35
# 12    45
# 13    35
# Name: Units Sold, dtype: int64

# %%
coffee.sort_values(["Units Sold", "Coffee Type"], ascending =[1,0] )
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          20
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25
# 7    Thursday       Latte          30
# 2     Tuesday    Espresso          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
for index, row in coffee.iterrows():
    print(index)
    print(row["Units Sold"])
    print("\n\n")
# Out:
# 0
# 25
#
#
#
# 1
# 20
#
#
#
# 2
# 30
#
#
#
# 3
# 20
#
#
#
# 4
# 35
#
#
#
# 5
# 25
#
#
#
# 6
# 40
#
#
#
# 7
# 30
#
#
#
# 8
# 45
#
#
#
# 9
# 35
#
#
#
# 10
# 45
#
#
#
# 11
# 35
#
#
#
# 12
# 45
#
#
#
# 13
# 35

# %% [markdown]
# ## Filtering Data

# %%
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.loc[bios['height_cm'] > 215, ['name', 'height_cm'] ]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
bios[bios['height_cm']> 210][['name','height_cm']].head(15)
# Out:
#                        name  height_cm
# 5089     Viktor Pankrashkin      220.0
# 5572        Santiago Aldama      213.0
# 5583   Paulinho Villas Boas      217.0
# 5599      Vladimir Andreyev      215.0
# 5609        Franjo Arapović      211.0
# 5673         Gunther Behnke      221.0
# 5681           Walt Bellamy      211.0
# 5683   Aleksandr Belostenny      214.0
# 5689             Tom Bender      213.0
# 5716               Uwe Blab      218.0
# 5781         Tommy Burleson      223.0
# 5796          Andy Campbell      218.0
# 5894             Mel Counts      213.0
# 5989            Vlade Divac      213.0
# 5992                 Olívia      211.0

# %%
bios[(bios['height_cm']> 215) & (bios['weight_kg']>102)]
# Out:
#         athlete_id                   name   born_date               born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19         Moskva (Moscow)
# 5583          5606   Paulinho Villas Boas  1963-01-26               São Paulo
# 5673          5696         Gunther Behnke  1963-01-19              Leverkusen
# 5716          5739               Uwe Blab  1962-03-26        München (Munich)
# 6223          6250            Lars Hansen  1954-09-27  København (Copenhagen)
# 6270          6298            Hu Zhangbao  1963-04-05                     NaN
# 6409          6440       Sergey Kovalenko  1947-08-11                     NaN
# 6420          6451          Jānis Krūmiņš  1930-01-30                   Cēsis
# 6504          6537            Luc Longley  1969-01-19               Melbourne
# 6722          6755       Shaquille O'Neal  1972-03-06                  Newark
# 6937          6972         David Robinson  1965-08-06                Key West
# ...

# %%
bios[bios['name'].str.contains("keith | leo", case=False)]
# Out:
#         athlete_id               name   born_date       born_city  \
# 545            547      Sarah Leonard  1862-03-21             NaN
# 1897          1907       Keith Hanlon  1966-09-01             NaN
# 1940          1950      Irina Leonova  1961-02-03             NaN
# 2188          2198      Yury Leontyev  1961-08-14      Cheboksary
# 2760          2772      Edgar Leonard  1881-06-19     West Newton
# ...            ...                ...         ...             ...
# 131818      134652      Luca Leonardi  1991-01-01          Milano
# 132783      135686      Gift Leotlela  1998-05-12  Phuthaditjhaba
# 135392      138606      Ezio Leonetti  2002-10-15          Torino
# 138014      141401       Adriana Leon  1992-10-02     Mississauga
# 140623      144135  Giuseppe Leonardi  1996-07-31         Catania
#
#                    born_region born_country                              NOC  \
# 545                        NaN          NaN                    Great Britain
# ...

# %%
bios[bios['born_country'].isin(["USA","FRA","GBR"]) & (bios['name'].str.startswith("Keith"))]
# Out:
#         athlete_id                name   born_date             born_city  \
# 3505          3517       Keith Wallace  1961-03-29               Preston
# 12053        12118        Keith Hervey  1898-11-03                Fulham
# 14577        14674      Keith Harrison  1933-03-28            Birmingham
# 16166        16281      Keith Reynolds  1963-12-25              Solihull
# 18734        18862      Keith Sinclair  1945-06-26            Sunderland
# 29897        30123       Keith Langley  1961-06-03             Aldershot
# 34011        34275        Keith Remfry  1947-11-17                Ealing
# 46885        47234        Keith Collin  1937-01-18            Marylebone
# 50929        51288        Keith Carter  1924-08-30                 Akron
# 51185        51544       Keith Russell  1948-01-15                  Mesa
# 52913        53288      Keith Erickson  1944-04-19         San Francisco
# 55317        55712        Keith Boxell  1958-05-06               Clapham
# ...

# %%
bios.query('born_country=="USA" and born_city == "Seattle"')
# Out:
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# 133392      136331          Hans Struzyna  1989-03-31   Seattle  Washington
# 135448      138662  Maude Davis Crossland  2003-03-19   Seattle  Washington
# 136993      140229        Jenell Berhorst  2003-12-13   Seattle  Washington
# 143507      147159         Nevin Harrison  2002-06-02   Seattle  Washington
# 145446      149169       Corinne Stoddard  2001-08-15   Seattle  Washington
#
# ...

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          20
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee['price'] = 5.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25   5.99
# 1      Monday       Latte          20   5.99
# 2     Tuesday    Espresso          30   5.99
# 3     Tuesday       Latte          20   5.99
# 4   Wednesday    Espresso          35   5.99
# 5   Wednesday       Latte          25   5.99
# 6    Thursday    Espresso          40   5.99
# 7    Thursday       Latte          30   5.99
# 8      Friday    Espresso          45   5.99
# 9      Friday       Latte          35   5.99
# 10   Saturday    Espresso          45   5.99
# 11   Saturday       Latte          35   5.99
# 12     Sunday    Espresso          45   5.99
# 13     Sunday       Latte          35   5.99

# %%
import numpy as np
coffee['new_price'] = np.where(coffee['Coffee Type']=='Espresso',4.99,5.99 )

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25   5.99       4.99
# 1      Monday       Latte          20   5.99       5.99
# 2     Tuesday    Espresso          30   5.99       4.99
# 3     Tuesday       Latte          20   5.99       5.99
# 4   Wednesday    Espresso          35   5.99       4.99
# 5   Wednesday       Latte          25   5.99       5.99
# 6    Thursday    Espresso          40   5.99       4.99
# 7    Thursday       Latte          30   5.99       5.99
# 8      Friday    Espresso          45   5.99       4.99
# 9      Friday       Latte          35   5.99       5.99
# 10   Saturday    Espresso          45   5.99       4.99
# 11   Saturday       Latte          35   5.99       5.99
# 12     Sunday    Espresso          45   5.99       4.99
# 13     Sunday       Latte          35   5.99       5.99

# %%
coffee.drop(columns=['price'], inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       4.99
# 1      Monday       Latte          20       5.99
# 2     Tuesday    Espresso          30       4.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       4.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       4.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       4.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       4.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       4.99
# 13     Sunday       Latte          35       5.99

# %%
coffee_new = coffee.copy()

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee_new['price'] = np.where(coffee['Coffee Type']=='Espresso',4.99,5.99)

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25   4.99
# 1      Monday       Latte          15   5.99
# 2     Tuesday    Espresso          30   4.99
# 3     Tuesday       Latte          20   5.99
# 4   Wednesday    Espresso          35   4.99
# 5   Wednesday       Latte          25   5.99
# 6    Thursday    Espresso          40   4.99
# 7    Thursday       Latte          30   5.99
# 8      Friday    Espresso          45   4.99
# 9      Friday       Latte          35   5.99
# 10   Saturday    Espresso          45   4.99
# 11   Saturday       Latte          35   5.99
# 12     Sunday    Espresso          45   4.99
# 13     Sunday       Latte          35   5.99

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25   4.99
# 1      Monday       Latte          15   5.99
# 2     Tuesday    Espresso          30   4.99
# 3     Tuesday       Latte          20   5.99
# 4   Wednesday    Espresso          35   4.99
# 5   Wednesday       Latte          25   5.99
# 6    Thursday    Espresso          40   4.99
# 7    Thursday       Latte          30   5.99
# 8      Friday    Espresso          45   4.99
# 9      Friday       Latte          35   5.99
# 10   Saturday    Espresso          45   4.99
# 11   Saturday       Latte          35   5.99
# 12     Sunday    Espresso          45   4.99
# 13     Sunday       Latte          35   5.99

# %%
coffee_new['revenue'] = coffee_new['Units Sold']*coffee_new['price']

# %%
coffee_new.head()
# Out:
#          Day Coffee Type  Units Sold  price  revenue
# 0     Monday    Espresso          25   4.99   124.75
# 1     Monday       Latte          15   5.99    89.85
# 2    Tuesday    Espresso          30   4.99   149.70
# 3    Tuesday       Latte          20   5.99   119.80
# 4  Wednesday    Espresso          35   4.99   174.65

# %%
coffee_new.rename(columns={'price':'new price'},inplace= True)

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold  new price  revenue
# 0      Monday    Espresso          25       4.99   124.75
# 1      Monday       Latte          15       5.99    89.85
# 2     Tuesday    Espresso          30       4.99   149.70
# 3     Tuesday       Latte          20       5.99   119.80
# 4   Wednesday    Espresso          35       4.99   174.65
# 5   Wednesday       Latte          25       5.99   149.75
# 6    Thursday    Espresso          40       4.99   199.60
# 7    Thursday       Latte          30       5.99   179.70
# 8      Friday    Espresso          45       4.99   224.55
# 9      Friday       Latte          35       5.99   209.65
# 10   Saturday    Espresso          45       4.99   224.55
# 11   Saturday       Latte          35       5.99   209.65
# 12     Sunday    Espresso          45       4.99   224.55
# 13     Sunday       Latte          35       5.99   209.65

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new = bios.copy()

# %%
bios_new['first_name'] = bios_new['name'].str.split(' ').str[0]
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new.query('first_name == "Keith"')
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 99921       100722       Keith Carney  1970-02-03    Providence
# 102227      103168      Keith Beavers  1983-02-09        London
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# ...

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
#  10  first_name    145500 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 12.2+ MB

# %%
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'])

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   athlete_id     145500 non-null  int64
#  1   name           145500 non-null  object
#  2   born_date      143693 non-null  object
#  3   born_city      110908 non-null  object
#  4   born_region    110908 non-null  object
#  5   born_country   110908 non-null  object
#  6   NOC            145499 non-null  object
#  7   height_cm      106651 non-null  float64
#  8   weight_kg      102070 non-null  float64
#  9   died_date      33940 non-null   object
#  10  first_name     145500 non-null  object
#  11  born_datetime  143693 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(8)
# memory usage: 13.3+ MB

# %%
bios_new['born_year']= bios_new['born_datetime'].dt.year

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new.to_csv('./bios_new.csv', index=False)

# %%
bios['height_category'] = bios['height_cm'].apply(lambda x: 'Short' if x < 165 else ('Average' if x >=165 and x < 185 else 'Tall'))

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios['height_category'] == 'Short']
# Out:
#         athlete_id                   name   born_date        born_city  \
# 49              50         Gillian Gowers  1964-04-09              NaN
# 62              63          Jo Muggeridge  1969-04-03           London
# 128            129             Olga Nemes  1968-06-09      Târgu Mureș
# 171            172  Christina Zachariadou  1974-08-28  Athina (Athens)
# 192            193            Hui So Hung  1958-12-02              NaN
# ...            ...                    ...         ...              ...
# 144989      148700       Lotta Udnes Weng  1996-09-29        Lørenskog
# 144995      148706             Sandra Eie  1995-11-14             Oslo
# 145096      148809        Kamila Valiyeva  2006-04-26            Kazan
# 145474      149201      Nadine Hofstetter  1994-10-21           Romoos
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
#
#                  born_region born_country                   NOC  height_cm  \
# ...

# %%
def categorize_athlete(row):
    if row['height_cm'] < 175 and row['weight_kg'] < 70:
        return 'LightWeight'
    elif row['height_cm'] <185 and row['weight_kg'] <=80:
        return 'MiddleWeight'
    else:
        return 'heavyweight'
    
##1 is rows and 0 is for columns in axis parameter
bios['Weight_category'] = bios.apply(categorize_athlete,axis=1)

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category Weight_category
# 0  1960-10-02            Tall     heavyweight
# 1         NaN         Average    MiddleWeight
# 2  1994-07-17         Average    MiddleWeight
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
nocs = pd.read_csv('./noc_regions.csv')

# %%
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios_new = pd.merge(bios,nocs,left_on='born_country', right_on='NOC', how='inner', suffixes=['bios','nocs'])

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country NOCbios  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date NOCnocs  region notes
# 0  1960-10-02     FRA  France   NaN
# 1         NaN     FRA  France   NaN
# 2  1994-07-17     FRA  France   NaN
# 3  1978-03-20     FRA  France   NaN
# ...

# %%
bios_new.rename(columns={'region':'born_country_full'}, inplace=True)

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country NOCbios  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date NOCnocs born_country_full notes
# 0  1960-10-02     FRA            France   NaN
# 1         NaN     FRA            France   NaN
# 2  1994-07-17     FRA            France   NaN
# ...

# %%
bios_new[bios_new['NOCbios']!=bios_new['born_country_full']][['name','NOCbios','born_country_full']]
# Out:
#                        name              NOCbios born_country_full
# 4              Albert Canet               France                UK
# 14               Guy Forget               France           Morocco
# 32          Helen Aitchison        Great Britain                UK
# 33        Geraldine Beamish        Great Britain                UK
# 34             Dora Boothby        Great Britain                UK
# ...                     ...                  ...               ...
# 110630         Shakeel John  Trinidad and Tobago          Trinidad
# 110632   Landysh Falyakhova                  ROC            Russia
# 110634    Polina Luchnikova                  ROC            Russia
# 110635  Valeriya Merkusheva                  ROC            Russia
# 110636      Yuliya Smirnova                  ROC            Russia
#
# [38349 rows x 3 columns]

# %%
usa = bios[bios['born_country']=='USA'].copy()
ind = bios[(bios['born_country']=='IND') & (bios['born_region']=='Punjab')].copy()

# %%
ind
# Out:
#         athlete_id                   name   born_date  born_city born_region  \
# 748            752              Anil Kaul  1964-12-25   Amritsar      Punjab
# 3878          3891        Gurcharan Singh  1977-04-10    Rurewal      Punjab
# 3879          3892             Kaur Singh  1950-08-09    Sangrur      Punjab
# 16474        16590     Amar Singh Billing  1944-01-10    Patiala      Punjab
# 17022        17140              Wazir Ali  1928-02-15  Jalandhar      Punjab
# ...            ...                    ...         ...        ...         ...
# 131634      134450         Gurpreet Singh  1987-12-19   Amritsar      Punjab
# 133666      136644        Ramandeep Singh  1993-04-01  Gurdaspur      Punjab
# 133667      136645      Harmanpreet Singh  1996-01-06   Amritsar      Punjab
# 133677      136659          Manpreet Kaur  1996-03-05    Patiala      Punjab
# 140226      143728  Simranjit Kaur Baatth  1995-07-10     Chakar      Punjab
#
# ...

# %%
new_df = pd.concat([usa,ind])

# %%
new_df.tail()
# Out:
#         athlete_id                   name   born_date  born_city born_region  \
# 131634      134450         Gurpreet Singh  1987-12-19   Amritsar      Punjab
# 133666      136644        Ramandeep Singh  1993-04-01  Gurdaspur      Punjab
# 133667      136645      Harmanpreet Singh  1996-01-06   Amritsar      Punjab
# 133677      136659          Manpreet Kaur  1996-03-05    Patiala      Punjab
# 140226      143728  Simranjit Kaur Baatth  1995-07-10     Chakar      Punjab
#
#        born_country    NOC  height_cm  weight_kg died_date
# 131634          IND  India      176.0       81.0       NaN
# 133666          IND  India      179.0       70.0       NaN
# 133667          IND  India      177.0       70.0       NaN
# 133677          IND  India      170.0       89.0       NaN
# 140226          IND  India        NaN        NaN       NaN

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
combined_df = pd.merge(results,bios,on='athlete_id', how='left')
combined_df
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
# ...
